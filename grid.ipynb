# %%
import pygame
import sys
import math

pygame.init()

width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("Midpoint Circle Algorithm with Rotation")

# Colors
black = (0, 0, 0)
white = (255, 255, 255)
red=(255, 0, 0)


circle_radius = 50
circle_center = [width // 2, height // 2]
rotation_angle = 0

def draw_circle(radius, center):
    x, y = radius, 0
    p = 1 - radius 

    while x >= y:
       
        draw_symmetric_points(center, x, y)

        if p <= 0:
            y += 1
            p = p + 2 * y + 1
        else:
            x -= 1
            y += 1
            p = p + 2 * (y - x) + 1

def draw_symmetric_points(center, x, y):
    plot_points(center, x, y)
    plot_points(center, y, x)
    plot_points(center, -x, y)
    plot_points(center, -y, x)
    plot_points(center, -x, -y)
    plot_points(center, -y, -x)
    plot_points(center, x, -y)
    plot_points(center, y, -x)

def plot_points(center, x, y):
    
   
    pygame.draw.rect(screen,red, (center[0] + x, center[1] - y, 1, 1))
    pygame.draw.rect(screen, red, (center[0] + y, center[1] - x, 1, 1))


def rotate_circle(angle):
    rotated_x = int(circle_radius * math.cos(math.radians(angle)))
    rotated_y = int(circle_radius * math.sin(math.radians(angle)))
    return [circle_center[0] + rotated_x, circle_center[1] - rotated_y]

while True:
    screen.fill(black)

    pygame.draw.line(screen, white, (width // 2, 0), (width // 2, height))
    pygame.draw.line(screen, white, (0, height // 2), (width, height // 2))
    rotated_circle_center = rotate_circle(rotation_angle)
    draw_circle(circle_radius, rotated_circle_center)

    pygame.display.flip()
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
        elif event.type == pygame.KEYDOWN:
            rotation_angle += 45
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
import pygame
import sys
import math

pygame.init()

width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("Midpoint Circle Algorithm with Rotation")

# Colors
black = (0, 0, 0)
white = (255, 255, 255)
red = (255, 0, 0)

circle_radius = 50
min_distance = 100  # Minimum distance between circle center and axis center
circle_center = [width // 2, height // 2 - min_distance]  # Initial position with a minimum distance
rotation_angle = 0

def draw_circle(radius, center):
    x, y = radius, 0
    p = 1 - radius

    while x >= y:
        draw_symmetric_points(center, x, y)

        if p <= 0:
            y += 1
            p = p + 2 * y + 1
        else:
            x -= 1
            y += 1
            p = p + 2 * (y - x) + 1

def draw_symmetric_points(center, x, y):
    plot_points(center, x, y)
    plot_points(center, y, x)
    plot_points(center, -x, y)
    plot_points(center, -y, x)
    plot_points(center, -x, -y)
    plot_points(center, -y, -x)
    plot_points(center, x, -y)
    plot_points(center, y, -x)

def plot_points(center, x, y):
    pygame.draw.rect(screen, red, (center[0] + x, center[1] - y, 1, 1))
    pygame.draw.rect(screen, red, (center[0] + y, center[1] - x, 1, 1))

def rotate_circle(angle):
    rotated_x = int(circle_radius * math.cos(math.radians(angle)))
    rotated_y = int(circle_radius * math.sin(math.radians(angle)))
    return [circle_center[0] + rotated_x, circle_center[1] - rotated_y]

while True:
    screen.fill(black)

    pygame.draw.line(screen, white, (width // 2, 0), (width // 2, height))
    pygame.draw.line(screen, white, (0, height // 2 - min_distance), (width, height // 2 - min_distance))
    
    rotated_circle_center = rotate_circle(rotation_angle)
    draw_circle(circle_radius, rotated_circle_center)

    pygame.display.flip()
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
        elif event.type == pygame.KEYDOWN:
            rotation_angle += 45
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.1)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Ahsan Al Bashar\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
